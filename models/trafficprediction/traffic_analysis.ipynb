# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import tensorflow
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras import callbacks
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("traffic.csv")
data.head()
# Out:
#               DateTime  Junction  Vehicles           ID
# 0  2015-11-01 00:00:00         1        15  20151101001
# 1  2015-11-01 01:00:00         1        13  20151101011
# 2  2015-11-01 02:00:00         1        10  20151101021
# 3  2015-11-01 03:00:00         1         7  20151101031
# 4  2015-11-01 04:00:00         1         9  20151101041

# %%
data["DateTime"]= pd.to_datetime(data["DateTime"])
data = data.drop(["ID"], axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48120 entries, 0 to 48119
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  48120 non-null  datetime64[ns]
#  1   Junction  48120 non-null  int64
#  2   Vehicles  48120 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 1.1 MB

# %%
df=data.copy()
colors = [ "#FFD4DB","#BBE7FE","#D3B5E5","#dfe2b6"]
plt.figure(figsize=(20,4),facecolor="#627D78")
Time_series=sns.lineplot(x=df['DateTime'],y="Vehicles",data=df, hue="Junction", palette=colors)
Time_series.set_title("Traffic On Junctions Over Years")
Time_series.set_ylabel("Number of Vehicles")
Time_series.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
df["Year"]= df['DateTime'].dt.year
df["Month"]= df['DateTime'].dt.month
df["Date_no"]= df['DateTime'].dt.day
df["Hour"]= df['DateTime'].dt.hour
df["Day"]= df.DateTime.dt.strftime("%A")
df.head()
# Out:
#              DateTime  Junction  Vehicles  Year  Month  Date_no  Hour     Day
# 0 2015-11-01 00:00:00         1        15  2015     11        1     0  Sunday
# 1 2015-11-01 01:00:00         1        13  2015     11        1     1  Sunday
# 2 2015-11-01 02:00:00         1        10  2015     11        1     2  Sunday
# 3 2015-11-01 03:00:00         1         7  2015     11        1     3  Sunday
# 4 2015-11-01 04:00:00         1         9  2015     11        1     4  Sunday

# %%
new_features = [ "Year","Month", "Date_no", "Hour", "Day"]

for i in new_features:
    plt.figure(figsize=(10,2),facecolor="#627D78")
    ax=sns.lineplot(x=df[i],y="Vehicles",data=df, hue="Junction", palette=colors )
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(12,5),facecolor="#627D78")
count = sns.countplot(data=df, x =df["Year"], hue="Junction", palette=colors)
count.set_title("Count Of Traffic On Junctions Over Years")
count.set_ylabel("Number of Vehicles")
count.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
corrmat = df.drop('Day', axis=1).corr()
plt.subplots(figsize=(10,10),facecolor="#627D78")
sns.heatmap(corrmat,cmap= "Pastel2",annot=True,square=True, )
# Out:
# <Axes: >

# %%
sns.pairplot(data=df, hue= "Junction",palette=colors)

# %%
df_J = data.pivot(columns="Junction", index="DateTime")
df_J.describe()
# Out:
#               Vehicles
# Junction             1             2             3            4
# count     14592.000000  14592.000000  14592.000000  4344.000000
# mean         45.052906     14.253221     13.694010     7.251611
# std          23.008345      7.401307     10.436005     3.521455
# min           5.000000      1.000000      1.000000     1.000000
# 25%          27.000000      9.000000      7.000000     5.000000
# 50%          40.000000     13.000000     11.000000     7.000000
# 75%          59.000000     17.000000     18.000000     9.000000
# max         156.000000     48.000000    180.000000    36.000000

# %%
df_1 = df_J[[('Vehicles', 1)]]
df_2 = df_J[[('Vehicles', 2)]]
df_3 = df_J[[('Vehicles', 3)]]
df_4 = df_J[[('Vehicles', 4)]]
df_4 = df_4.dropna()

list_dfs = [df_1, df_2, df_3, df_4]
for i in list_dfs:
    i.columns= i.columns.droplevel(level=1)

# %%
def Sub_Plots4(df_1, df_2,df_3,df_4,title):
    fig, axes = plt.subplots(4, 1, figsize=(15, 8),facecolor="#627D78", sharey=True)
    fig.suptitle(title)
    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[0])
    #pl_1=plt.ylabel()
    axes[0].set(ylabel ="Junction 1")
    pl_2=sns.lineplot(ax=axes[1],data=df_2,color=colors[1])
    axes[1].set(ylabel ="Junction 2")
    pl_3=sns.lineplot(ax=axes[2],data=df_3,color=colors[2])
    axes[2].set(ylabel ="Junction 3")
    pl_4=sns.lineplot(ax=axes[3],data=df_4,color=colors[3])
    axes[3].set(ylabel ="Junction 4")

Sub_Plots4(df_1.Vehicles, df_2.Vehicles,df_3.Vehicles,df_4.Vehicles,"Dataframes Before Transformation")

# %%
def Normalize(df,col):
    average = df[col].mean()
    stdev = df[col].std()
    df_normalized = (df[col] - average) / stdev
    df_normalized = df_normalized.to_frame()
    return df_normalized, average, stdev

def Difference(df,col, interval):
    diff = []
    for i in range(interval, len(df)):
        value = df[col][i] - df[col][i - interval]
        diff.append(value)
    return diff

# %%
df_N1, av_J1, std_J1 = Normalize(df_1, "Vehicles")
Diff_1 = Difference(df_N1, col="Vehicles", interval=(24*7)) #taking a week's diffrence
df_N1 = df_N1[24*7:]
df_N1.columns = ["Norm"]
df_N1["Diff"]= Diff_1

df_N2, av_J2, std_J2 = Normalize(df_2, "Vehicles")
Diff_2 = Difference(df_N2, col="Vehicles", interval=(24)) #taking a day's diffrence
df_N2 = df_N2[24:]
df_N2.columns = ["Norm"]
df_N2["Diff"]= Diff_2

df_N3, av_J3, std_J3 = Normalize(df_3, "Vehicles")
Diff_3 = Difference(df_N3, col="Vehicles", interval=1) #taking an hour's diffrence
df_N3 = df_N3[1:]
df_N3.columns = ["Norm"]
df_N3["Diff"]= Diff_3

df_N4, av_J4, std_J4 = Normalize(df_4, "Vehicles")
Diff_4 = Difference(df_N4, col="Vehicles", interval=1) #taking an hour's diffrence
df_N4 = df_N4[1:]
df_N4.columns = ["Norm"]
df_N4["Diff"]= Diff_4

# %%
Sub_Plots4(df_N1.Diff, df_N2.Diff,df_N3.Diff,df_N4.Diff,"Dataframes After Transformation")

# %%
#Stationary Check for the time series Augmented Dickey Fuller test
def Stationary_check(df):
    check = adfuller(df.dropna())
    print(f"ADF Statistic: {check[0]}")
    print(f"p-value: {check[1]}")
    print("Critical Values:")
    for key, value in check[4].items():
        print('\t%s: %.3f' % (key, value))
    if check[0] > check[4]["1%"]:
        print("Time Series is Non-Stationary")
    else:
        print("Time Series is Stationary")

List_df_ND = [ df_N1["Diff"], df_N2["Diff"], df_N3["Diff"], df_N4["Diff"]]
print("Checking the transformed series for stationarity:")
for i in List_df_ND:
    print("\n")
    Stationary_check(i)
# Out:
# Checking the transformed series for stationarity:
#
#
# ADF Statistic: -15.265303390415532
# p-value: 4.798539876395309e-28
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -21.79589102694006
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -28.00175990883286
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -17.97909256305256
# p-value: 2.778787532594863e-30
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary

# %%
df_J1 = df_N1["Diff"].dropna()
df_J1 = df_J1.to_frame()

df_J2 = df_N2["Diff"].dropna()
df_J2 = df_J2.to_frame()

df_J3 = df_N3["Diff"].dropna()
df_J3 = df_J3.to_frame()

df_J4 = df_N4["Diff"].dropna()
df_J4 = df_J4.to_frame()

# %%
def Split_data(df):
    training_size = int(len(df)*0.90)
    data_len = len(df)
    train, test = df[0:training_size],df[training_size:data_len]
    train, test = train.values.reshape(-1, 1), test.values.reshape(-1, 1)
    return train, test

J1_train, J1_test = Split_data(df_J1)
J2_train, J2_test = Split_data(df_J2)
J3_train, J3_test = Split_data(df_J3)
J4_train, J4_test = Split_data(df_J4)

# %%
def TnF(df):
    end_len = len(df)
    X = []
    y = []
    steps = 32
    for i in range(steps, end_len):
        X.append(df[i - steps:i, 0])
        y.append(df[i, 0])
    X, y = np.array(X), np.array(y)
    return X ,y

def FeatureFixShape(train, test):
    train = np.reshape(train, (train.shape[0], train.shape[1], 1))
    test = np.reshape(test, (test.shape[0],test.shape[1],1))
    return train, test

# %%
X_trainJ1, y_trainJ1 = TnF(J1_train)
X_testJ1, y_testJ1 = TnF(J1_test)
X_trainJ1, X_testJ1 = FeatureFixShape(X_trainJ1, X_testJ1)

X_trainJ2, y_trainJ2 = TnF(J2_train)
X_testJ2, y_testJ2 = TnF(J2_test)
X_trainJ2, X_testJ2 = FeatureFixShape(X_trainJ2, X_testJ2)

X_trainJ3, y_trainJ3 = TnF(J3_train)
X_testJ3, y_testJ3 = TnF(J3_test)
X_trainJ3, X_testJ3 = FeatureFixShape(X_trainJ3, X_testJ3)

X_trainJ4, y_trainJ4 = TnF(J4_train)
X_testJ4, y_testJ4 = TnF(J4_test)
X_trainJ4, X_testJ4 = FeatureFixShape(X_trainJ4, X_testJ4)

# %%
def GRU_model(X_Train, y_Train, X_Test):
    early_stopping = callbacks.EarlyStopping(min_delta=0.001,patience=10, restore_best_weights=True)
    model = Sequential()
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    model.compile(optimizer=SGD(decay=1e-7, momentum=0.9),loss='mean_squared_error')
    model.fit(X_Train,y_Train, epochs=50, batch_size=150,callbacks=[early_stopping])
    pred_GRU= model.predict(X_Test)
    return pred_GRU

# %%
def RMSE_Value(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))
    return rmse

def PredictionsPlot(test,predicted,m):
    plt.figure(figsize=(12,5),facecolor="#627D78")
    plt.plot(test, color=colors[m],label="True Value",alpha=0.5 )
    plt.plot(predicted, color="#627D78",label="Predicted Values")
    plt.title("GRU Traffic Prediction Vs True values")
    plt.xlabel("DateTime")
    plt.ylabel("Number of Vehicles")
    plt.legend()
    plt.show()

# %%
PredJ1 = GRU_model(X_trainJ1,y_trainJ1,X_testJ1)
# Out:
# Epoch 1/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0928
# Epoch 2/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0653
# Epoch 3/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0629
# Epoch 4/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0626
# Epoch 5/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0617
# Epoch 6/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0615
# Epoch 7/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0602
# Epoch 8/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0592
# Epoch 9/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0549
# Epoch 10/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0562
# Epoch 11/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0609
# Epoch 12/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0579
# Epoch 13/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0533
# Epoch 14/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0530
# Epoch 15/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0541
# Epoch 16/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0531
# Epoch 17/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0535
# Epoch 18/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0525
# Epoch 19/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0523
# Epoch 20/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0515
# Epoch 21/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0484
# Epoch 22/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0514
# Epoch 23/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0503
# Epoch 24/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0496
# Epoch 25/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0501
# Epoch 26/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0505
# Epoch 27/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0527
# Epoch 28/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0523
# Epoch 29/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0486
# Epoch 30/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0503
# Epoch 31/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0488
# Epoch 32/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0484
# Epoch 33/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0488
# Epoch 34/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0513
# Epoch 35/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0485
# Epoch 36/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0498
# Epoch 37/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0458
# Epoch 38/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0489
# Epoch 39/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0486
# Epoch 40/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0468
# Epoch 41/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0501
# Epoch 42/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0467
# Epoch 43/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0466
# Epoch 44/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0475
# Epoch 45/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0503
# Epoch 46/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0483
# Epoch 47/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0478
# Epoch 48/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0471
# Epoch 49/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0469
# Epoch 50/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0478
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step

# %%
RMSE_J1=RMSE_Value(y_testJ1,PredJ1)
PredictionsPlot(y_testJ1,PredJ1,0)
# Out:
# The root mean squared error is 0.246900004090148.

# %%
PredJ2 = GRU_model(X_trainJ2,y_trainJ2,X_testJ2)
# Out:
# Epoch 1/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2688
# Epoch 2/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2036
# Epoch 3/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1996
# Epoch 4/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2024
# Epoch 5/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1950
# Epoch 6/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1934
# Epoch 7/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1838
# Epoch 8/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1954
# Epoch 9/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1885
# Epoch 10/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1896
# Epoch 11/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1934
# Epoch 12/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1925
# Epoch 13/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1869
# Epoch 14/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1872
# Epoch 15/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1877
# Epoch 16/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1828
# Epoch 17/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1866
# Epoch 18/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1859
# Epoch 19/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1869
# Epoch 20/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1861
# Epoch 21/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1848
# Epoch 22/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1864
# Epoch 23/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1854
# Epoch 24/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1824
# Epoch 25/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1892
# Epoch 26/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1857
# Epoch 27/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1886
# Epoch 28/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1856
# Epoch 29/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1797
# Epoch 30/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1829
# Epoch 31/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1863
# Epoch 32/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1872
# Epoch 33/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1888
# Epoch 34/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1847
# Epoch 35/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1883
# Epoch 36/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1861
# Epoch 37/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1881
# Epoch 38/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1851
# Epoch 39/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1805
# Epoch 40/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1907
# Epoch 41/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1843
# Epoch 42/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1880
# Epoch 43/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1814
# Epoch 44/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1773
# Epoch 45/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1770
# Epoch 46/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1825
# Epoch 47/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1832
# Epoch 48/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1758
# Epoch 49/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1793
# Epoch 50/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1858
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step

# %%
RMSE_J2=RMSE_Value(y_testJ2,PredJ2)
PredictionsPlot(y_testJ2,PredJ2,1)
# Out:
# The root mean squared error is 0.5553616050835748.

# %%
PredJ3 = GRU_model(X_trainJ3,y_trainJ3,X_testJ3)
# Out:
# Epoch 1/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.3100
# Epoch 2/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2945
# Epoch 3/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2665
# Epoch 4/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3207
# Epoch 5/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2787
# Epoch 6/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2987
# Epoch 7/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2837
# Epoch 8/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2750
# Epoch 9/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3029
# Epoch 10/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.2977
# Epoch 11/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2547
# Epoch 12/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2830
# Epoch 13/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2981
# Epoch 14/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.2768
# Epoch 15/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2626
# Epoch 16/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2850
# Epoch 17/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2929
# Epoch 18/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.2725
# Epoch 19/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2714
# Epoch 20/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2428
# Epoch 21/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2759
# Epoch 22/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2992
# Epoch 23/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2646
# Epoch 24/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2797
# Epoch 25/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2519
# Epoch 26/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2554
# Epoch 27/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2537
# Epoch 28/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2727
# Epoch 29/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2909
# Epoch 30/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2543
# Epoch 31/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2879
# Epoch 32/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3110
# Epoch 33/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2675
# Epoch 34/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3001
# Epoch 35/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2648
# Epoch 36/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2570
# Epoch 37/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2731
# Epoch 38/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.2782
# Epoch 39/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2890
# Epoch 40/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2638
# Epoch 41/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2582
# Epoch 42/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2582
# Epoch 43/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2671
# Epoch 44/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2540
# Epoch 45/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2618
# Epoch 46/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.2621
# Epoch 47/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2579
# Epoch 48/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2565
# Epoch 49/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2460
# Epoch 50/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2588
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step

# %%
RMSE_J3=RMSE_Value(y_testJ3,PredJ3)
PredictionsPlot(y_testJ3,PredJ3,2)
# Out:
# The root mean squared error is 0.6087303012567822.

# %%
PredJ4 = GRU_model(X_trainJ4,y_trainJ4,X_testJ4)
# Out:
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.7191
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6763
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6824
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6751
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.7044
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6772
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6781
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6596
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6654
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.7215
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6675
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6525
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7200
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6949
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6748
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6662
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6643
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6502
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6889
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6902
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6671
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6503
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6781
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6840
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6694
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6848
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6516
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7123
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6372
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6521
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6862
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6634
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6749
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6855
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6684
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6466
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6550
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6720
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6447
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6682
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6206
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6318
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6526
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6554
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6243
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5975
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6611
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6611
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5923
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5936
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step

# %%
RMSE_J4=RMSE_Value(y_testJ4,PredJ4)
PredictionsPlot(y_testJ4,PredJ4,3)
# Out:
# The root mean squared error is 1.0363923332391172.
